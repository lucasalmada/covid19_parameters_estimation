# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import scipy as sp
from scipy.optimize import minimize
import numpy as np
from epimodels.discrete.models import SEQIAHR
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline

# %% [markdown]
# # SEIAHR model

# %%
model  = SEQIAHR()

# %%
pars = {
    'chi': .5,#0.05188433291603778,
    'phi': 0.012413633926076584,
    'beta': 0.2,
    'rho': 0.6,
    'delta': 0.1,
    'gamma': 0.04,
    'alpha': 0.3413355572047603,
    'mu': 0.02359234606623134,
    'p': 0.7693029079871165,
    'q': 50,#6.635760900566002,
    'r': 55#28.637912453634094
}
model([.99, 0, 1e-6, 0, 0, 0, 0, 0], [0, 300], 1, pars)

# %%
model.plot_traces(vars=['E','I','A'])
plt.savefig('containment.png', dpi=300)
plt.title('');

# %% [markdown]
# ## Load data

# %%
cases = pd.read_csv('covid19_18_06.csv')
# Pegando os casos do Brasil.io
# cases = pd.read_csv('https://brasil.io/dataset/covid19/caso_full/?format=csv')
cases.date = pd.to_datetime(cases.date)

# %%
df_states = cases[cases.place_type!='state'].groupby(['date','state']).sum()
df_states.reset_index(inplace=True)
df_states.set_index('date', inplace=True)

# %%
# df_states.set_index('date', inplace=True)
fig,ax = plt.subplots(1,1,figsize=(15,8))

for uf in ['SP','RJ','MG','CE','RS', 'PE', 'AM', 'BA']:
    df_states[df_states.state==uf].last_available_confirmed.plot(ax=ax,style='-o', label=uf, grid=True)

ax.legend()
#plt.savefig('Casos_confirmados_estados.png',dpi=200)

# %% [markdown]
# #### Simulação SP

# %%
df_SP = df_states[df_states.state=='SP'][['last_available_confirmed','new_confirmed','last_available_deaths', 'new_deaths']]
df_SP.columns = ['Confirmados','Casos_novos','Mortes','Mortes_novas']

# %%
popSP = 12.28e6
subnot=0.8

def plot_fit(data, pop, model, offset):
    f,(ax1,ax2) = plt.subplots(2,1,figsize=(15,10))
    data.plot(ax=ax1,style=':*', grid=True)
    ax1.plot(model.traces['time'][offset:]-offset,model.traces['C'][offset:]*pop*subnot, label='casos' );
    ax1.plot(model.traces['time'][offset:]-offset,model.traces['D'][offset:]*pop, label='Mortes' );
    ax1.legend();
    ax2.plot(model.traces['time'][offset:]-offset,model.traces['I'][offset:]*pop, label='Infected')
    ax2.plot(model.traces['time'][offset:]-offset,model.traces['A'][offset:]*pop, label='Asymptomatic')
#     ax2.plot(model.traces['time'][offset:]-offset,model.traces['S'][offset:]*pop, label='Susceptible')
    ax2.grid()
    ax2.legend()
plot_fit(df_SP[['Confirmados', 'Mortes']], popSP, model, 30);

# %%
pardict = {
 'chi': .5,#0.05188433291603778,
    'phi': 0.012413633926076584,
    'beta': 0.2,
    'rho': 0.6,
    'delta': 0.1,
    'gamma': 0.04,
    'alpha': 0.3413355572047603,
    'mu': 0.02359234606623134,
    'p': 0.7693029079871165,
    'q': 50,#6.635760900566002,
    'r': 55, #28.637912453634094
    'offset': 25
}

# %%
parn = list(pardict.keys())
parv = list(pardict.values())

# %%
data = df_SP[['Confirmados', 'Mortes']]
ld = len(data)
def loss(pars):
    pars = list(pars)
    offs = int(np.round(pars.pop()))
#     print(dict(zip(parn[:-1],pars)))
    model([.99, 0, 1e-6, 0, 0, 0, 0, 0], [0, ld+offs], 1, dict(zip(parn[:-1],pars)))
    C=model.traces['C'][offs:offs+ld]*popSP*subnot
    D=model.traces['D'][offs:offs+ld]*popSP
    loss  = sum((data.Confirmados-C)**2) +sum((data.Mortes-D)**2)/2*len(data)
    return loss

# %%
res = minimize(
    loss,
    parv,
    #          method='COBYLA',
    method='L-BFGS-B',
    #                method='TNC',
    bounds=[(0.0, 1.0), (0.0, 1.0), (0.0, 1.0), (0.0, 2.0), (0.0, 1.0),
            (0.0, 2.0), (0.0, 1.0), (0.0, 1.0),(.35, 1), (0, 30), (0, 90),
                                                   (0, 40)],
    options={'maxiter': 250})
print("Sucess: ", res['success'])
# Out:
# Sucess:  False

# %%
def R0(prs):
    chi,phi,beta,rho, delta,gamma,alpha,mu,p,q,r,offset=prs
    B = beta*chi-beta
    return -B*(p*phi+gamma+(delta-gamma)*p)/(gamma*(delta+phi))
print(dict(zip(parn,res['x'])))
plot_fit(data,popSP, model, int(res['x'][-1]))
print("R0=", R0(res['x']))
# Out:
# {'chi': 0.0, 'phi': 0.34819827778924045, 'beta': 0.9979042489067133, 'rho': 1.7100172640865556, 'delta': 0.3673795815699766, 'gamma': 1.4107014957156412, 'alpha': 1.0, 'mu': 0.2758626013348138, 'p': 0.35, 'q': 30.0, 'r': 0.0, 'offset': 25.0}
# R0= 1.1540366420499857

# %% [markdown]
# ## Optimization with PuLP

# %%
import pulp as pl

# %%
opt_prob = pl.LpProblem("Parameter_finding", pl.LpMinimize)
chi = pl.LpVariable('chi', lowBound=0, cat='Continuous')
phi = pl.LpVariable('phi', lowBound=0, upBound=1, cat='Continuous')
beta = pl.LpVariable('beta', lowBound=0, cat='Continuous')
rho = pl.LpVariable('rho', lowBound=0, cat='Continuous')
delta = pl.LpVariable('delta', lowBound=0, cat='Continuous')
alpha = pl.LpVariable('alpha', lowBound=0, cat='Continuous')
mu = pl.LpVariable('mu', lowBound=0, cat='Continuous')
p = pl.LpVariable('p', lowBound=0, upBound=1, cat='Continuous')
q = pl.LpVariable('q', lowBound=0, cat='Continuous')
r = pl.LpVariable('r', lowBound=0, cat='Continuous')
offset = pl.LpVariable('offset', lowBound=0, upBound=60, cat='Integer')

# %%
#adding the loss function
opt_prob += loss([chi,phi,beta,rho,delta,alpha,mu,p,q,r,offset])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55     try:
# ---> 56         return getattr(obj, method)(*args, **kwds)
#      57
#
# TypeError: round() got an unexpected keyword argument 'decimals'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-12eb69b8c7b7> in <module>
#       1 #adding the loss function
# ----> 2 opt_prob += loss([chi,phi,beta,rho,delta,alpha,mu,p,q,r,offset])
#
# <ipython-input-37-2c163d12f098> in loss(pars)
#       3 def loss(pars):
#       4     pars = list(pars)
# ----> 5     offs = int(np.round(pars.pop()))
#       6 #     print(dict(zip(parn[:-1],pars)))
#       7     model([.99, 0, 1e-6, 0, 0, 0, 0, 0], [0, ld+offs], 1, dict(zip(parn[:-1],pars)))
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\numpy\core\fromnumeric.py in round_(a, decimals, out)
#    3380     around : equivalent function; see for details.
#    3381     """
# -> 3382     return around(a, decimals=decimals, out=out)
#    3383
#    3384
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\numpy\core\fromnumeric.py in around(a, decimals, out)
#    3005
#    3006     """
# -> 3007     return _wrapfunc(a, 'round', decimals=decimals, out=out)
#    3008
#    3009
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      64     # a downstream library like 'pandas'.
#      65     except (AttributeError, TypeError):
# ---> 66         return _wrapit(obj, method, *args, **kwds)
#      67
#      68
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\numpy\core\fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      44     except AttributeError:
#      45         wrap = None
# ---> 46     result = getattr(asarray(obj), method)(*args, **kwds)
#      47     if wrap:
#      48         if not isinstance(result, mu.ndarray):
#
# AttributeError: 'LpVariable' object has no attribute 'rint'

# %% [markdown]
# ## Tensorflow edward2 estimation

# %%
from tensorflow_probability import edward2 as ed

# %%
n = ed.Normal(0,1)
print(n**2)
# Out:
# tf.Tensor(0.10639655, shape=(), dtype=float32)
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: UserWarning: tfp.edward2 module is deprecated and will be removed on 2019-12-01. Use https://github.com/google/edward2 library instead.
#   """Entry point for launching an IPython kernel.

# %%
pars
# Out:
# {'chi': 0.5,
#  'phi': 0.012413633926076584,
#  'beta': 0.2,
#  'rho': 0.6,
#  'delta': 0.1,
#  'gamma': 0.04,
#  'alpha': 0.3413355572047603,
#  'mu': 0.02359234606623134,
#  'p': 0.7693029079871165,
#  'q': 50,
#  'r': 55.0}

# %%
mod  = SEQIAHR()
def ed_model():
    pars ={
    'chi': ed.Uniform(),# 0.05188433291603778,
    'phi': ed.Uniform(), #0.012413633926076584,
    'beta': ed.Uniform(),#0.47272459855759813,
    'rho': ed.Uniform(),#0.2190519831830368,
    'delta': ed.Uniform(), #0.04168480042146949,
    'alpha': ed.Uniform(),#0.3413355572047603,
    'mu': ed.Uniform(), #0.02359234606623134,
    'p': ed.Uniform(), #0.7693029079871165,
    'q': ed.Uniform(0,30), #6.635760900566002,
    'r': ed.Uniform(0,60), #28.637912453634094
            }
    return mod([.99, 0, 1e-6, 0, 0, 0, 0, 0], [0, 300], 1, pars)

# %%
ed_model()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-c3d7525828a2> in <module>
# ----> 1 ed_model()
#
# <ipython-input-64-0a8f31c19523> in ed_model()
#      13     'r': ed.Uniform(0,60), #28.637912453634094
#      14             }
# ---> 15     return mod([.99, 0, 1e-6, 0, 0, 0, 0, 0], [0, 300], 1, pars)
#      16
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\epimodels\discrete\models.py in __call__(self, *args, **kwargs)
#      78     def __call__(self, *args, **kwargs):
#      79         # args = self.get_args_from_redis()
# ---> 80         res = self.run(*args)
#      81         self.traces.update(res)
#      82         # return res
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\epimodels\discrete\models.py in model(self, inits, trange, totpop, params)
#     580
#     581         N = totpop
# --> 582         chi, phi, beta, rho, delta, gamma, alpha, mu, p, q, r = params.values()
#     583
#     584         for i in tspan[:-1]:
#
# ValueError: not enough values to unpack (expected 11, got 10)

# %%
plot_fit(data,popSP,ed_model(), 30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-70e0a9c8a4a3> in <module>
# ----> 1 plot_fit(data,popSP,ed_model(), 30)
#
# <ipython-input-64-0a8f31c19523> in ed_model()
#      13     'r': ed.Uniform(0,60), #28.637912453634094
#      14             }
# ---> 15     return mod([.99, 0, 1e-6, 0, 0, 0, 0, 0], [0, 300], 1, pars)
#      16
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\epimodels\discrete\models.py in __call__(self, *args, **kwargs)
#      78     def __call__(self, *args, **kwargs):
#      79         # args = self.get_args_from_redis()
# ---> 80         res = self.run(*args)
#      81         self.traces.update(res)
#      82         # return res
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\epimodels\discrete\models.py in model(self, inits, trange, totpop, params)
#     580
#     581         N = totpop
# --> 582         chi, phi, beta, rho, delta, gamma, alpha, mu, p, q, r = params.values()
#     583
#     584         for i in tspan[:-1]:
#
# ValueError: not enough values to unpack (expected 11, got 10)

# %%
data

# %% [markdown]
# ## PyMC4 Estimation

# %%
import pymc4 as pm
import tensorflow as tf
import arviz as az

# %%
mod  = SEQIAHR()

@tf.autograph.experimental.do_not_convert
def get_sim(pars):
    for k, v in pars.items():
#         print(k, type(v))
        try:
#             print(v.numpy())
            pars[k] = v.numpy()
        except:
#             print(dir(v))
#             sess = tf1.Session()
#             print(v.eval(session=sess))
            pars[k] = 0#v.eval(session=sess)
#         pars = {k:v.numpy() for k,v in pars.items()}
    popSP = 12.28e6
    offset = 30
    mod([.99, 0, 1e-6, 0, 0, 0, 0, 0], [0, 300], 1, pars)
    C=mod.traces['C'][offset:offset+ld]*popSP
    D=mod.traces['D'][offset:offset+ld]*popSP
    return C.astype('float32'),D.astype('float32')
    
    
@pm.model
def SEIAHR_model():
    chi = yield pm.Uniform('chi', 0,1)# 0.05188433291603778,
    phi = yield pm.Uniform('phi', 0,1) #0.012413633926076584,
    beta = yield pm.Uniform('beta', 0,1)#0.47272459855759813,
    rho = yield pm.Uniform('rho', 0,1)#0.2190519831830368,
    delta = yield pm.Uniform('delta', 0,1) #0.04168480042146949,
    alpha = yield pm.Uniform('alpha', 0,1)#0.3413355572047603,
    mu = yield pm.Uniform('mu', 0,1) #0.02359234606623134,
    p = yield pm.Uniform('p', 0,1) #0.7693029079871165,
    q = yield pm.Uniform('q',0,30) #6.635760900566002,
    r = yield pm.Uniform('r',0,60) #28.637912453634094
    
    pars = dict(zip(parn,[chi,phi,beta,rho,delta,alpha,mu,p,q,r]))
    res = get_sim(pars)
    casos, mortes = res
#     par_pois = yield pm.Exponential('lamb',1/100)
    incidencia = yield pm.Poisson('incidência', rate=casos, shape=(1,len(casos)))
    mortalidade = yield pm.Poisson('mortalidade', rate=mortes, shape=(1,len(mortes)))
#     Verossimilhanças
    L_casos = pm.Poisson('Lik_casos', rate=incidencia, observed=data.confirmed)
    L_mortes = pm.Poisson('Lik_mortes', rate=mortalidade, observed=data.deaths)

# %%
# %time data = pm.sample(SEIAHR_model(), num_chains=16)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\pymc4\inference\sampling.py in sample(model, num_samples, num_chains, burn_in, step_size, observed, state, nuts_kwargs, adaptation_kwargs, sample_chain_kwargs, xla)
#     100         deterministic_names,
#     101         state_,
# --> 102     ) = build_logp_and_deterministic_functions(model, state=state, observed=observed)
#     103     init_state = list(init.values())
#     104     init_keys = list(init.keys())
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\pymc4\inference\sampling.py in build_logp_and_deterministic_functions(model, observed, state)
#     173         raise ValueError("Can't use both `state` and `observed` arguments")
#     174
# --> 175     state, deterministic_names = initialize_sampling_state(model, observed=observed, state=state)
#     176
#     177     if not state.all_unobserved_values:
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\pymc4\inference\utils.py in initialize_sampling_state(model, observed, state)
#      25         The list of names of the model's deterministics
#      26     """
# ---> 27     _, state = flow.evaluate_model_transformed(model, observed=observed, state=state)
#      28     deterministic_names = list(state.deterministics)
#      29
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\pymc4\flow\executor.py in evaluate_model(self, model, state, _validate_state, values, observed)
#     457             try:
#     458                 with model_info["scope"]:
# --> 459                     dist = control_flow.send(return_value)
#     460                     if not isinstance(dist, MODEL_POTENTIAL_AND_DETERMINISTIC_TYPES):
#     461                         # prohibit any unknown type
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\pymc4\coroutine_model.py in control_flow(self)
#     214     def control_flow(self):
#     215         """Iterate over the random variables in the model."""
# --> 216         return (yield from self.genfn())
#
# <ipython-input-61-b447a98602e2> in SEIAHR_model()
#      36
#      37     pars = dict(zip(parn,[chi,phi,beta,rho,delta,alpha,mu,p,q,r]))
# ---> 38     res = get_sim(pars)
#      39     casos, mortes = res
#      40 #     par_pois = yield pm.Exponential('lamb',1/100)
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\autograph\impl\api.py in wrapper(*args, **kwargs)
#     300   def wrapper(*args, **kwargs):
#     301     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 302       return func(*args, **kwargs)
#     303
#     304   if inspect.isfunction(func) or inspect.ismethod(func):
#
# <ipython-input-61-b447a98602e2> in get_sim(pars)
#      16     popSP = 12.28e6
#      17     offset = 30
# ---> 18     mod([.99, 0, 1e-6, 0, 0, 0, 0, 0], [0, 300], 1, pars)
#      19     C=mod.traces['C'][offset:offset+ld]*popSP
#      20     D=mod.traces['D'][offset:offset+ld]*popSP
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\epimodels\discrete\models.py in __call__(self, *args, **kwargs)
#      78     def __call__(self, *args, **kwargs):
#      79         # args = self.get_args_from_redis()
# ---> 80         res = self.run(*args)
#      81         self.traces.update(res)
#      82         # return res
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\epimodels\discrete\models.py in model(self, inits, trange, totpop, params)
#     580
#     581         N = totpop
# --> 582         chi, phi, beta, rho, delta, gamma, alpha, mu, p, q, r = params.values()
#     583
#     584         for i in tspan[:-1]:
#
# ValueError: not enough values to unpack (expected 11, got 10)

# %%
az.plot_trace(data);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-485a999d7ee9> in <module>
# ----> 1 az.plot_trace(data);
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\arviz\plots\traceplot.py in plot_trace(data, var_names, filter_vars, transform, coords, divergences, kind, figsize, rug, lines, compact, compact_prop, combined, chain_prop, legend, plot_kwargs, fill_kwargs, rug_kwargs, hist_kwargs, trace_kwargs, rank_kwargs, ax, backend, backend_config, backend_kwargs, show)
#     173         divergence_data = False
#     174
# --> 175     data = get_coords(convert_to_dataset(data, group="posterior"), coords)
#     176
#     177     if transform is not None:
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\arviz\data\converters.py in convert_to_dataset(obj, group, coords, dims)
#     175     xarray.Dataset
#     176     """
# --> 177     inference_data = convert_to_inference_data(obj, group=group, coords=coords, dims=dims)
#     178     dataset = getattr(inference_data, group, None)
#     179     if dataset is None:
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\arviz\data\converters.py in convert_to_inference_data(obj, group, coords, dims, **kwargs)
#     131         raise ValueError(
#     132             "Can only convert {} to InferenceData, not {}".format(
# --> 133                 ", ".join(allowable_types), obj.__class__.__name__
#     134             )
#     135         )
#
# ValueError: Can only convert xarray dataarray, xarray dataset, dict, netcdf filename, numpy array, pystan fit, pymc3 trace, emcee fit, pyro mcmc fit, numpyro mcmc fit, cmdstan fit csv filename, cmdstanpy fit to InferenceData, not DataFrame
